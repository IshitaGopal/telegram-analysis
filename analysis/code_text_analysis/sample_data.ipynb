# %%
import pandas as pd

# %%
df = pd.read_csv('../processed_data/analysis_data/telegram_data_2020-08-09_2021-04-01.csv')

# %%
sample_10000 = df.sample(n=10000, random_state=1)

# %%
sample_10000.to_csv('../processed_data/analysis_data/telegram_data_2020-08-09_2021-04-01_sample_10000.csv', index=False)

# %%
emoji = pd.read_csv("../processed_data/text_analysis/emoji_sentiment_ranking.csv")

# %%
emoji
# Out:
#     Char Image[twemoji] Unicodecodepoint  Occurrences[5...max]  \
# 0      😂              😂          0x1f602                 14622
# 1      ❤              ❤           0x2764                  8050
# 2      ♥              ♥           0x2665                  7144
# 3      😍              😍          0x1f60d                  6359
# 4      😭              😭          0x1f62d                  5526
# ..   ...            ...              ...                   ...
# 746    ♮              ♮           0x266e                     5
# 747    🅾              🅾          0x1f17e                     5
# 748    🔄              🔄          0x1f504                     5
# 749    ☄              ☄           0x2604                     5
# 750    ☨              ☨           0x2628                     5
#
#      Position[0...1]  Neg[0...1]  Neut[0...1]  Pos[0...1]  \
# 0              0.805       0.247        0.285       0.468
# 1              0.747       0.044        0.166       0.790
# ...
